# %% [markdown]
# ## Intro
# * Remember to upload your own `.env` file that contains HF token
# * The python script can be found at `LLM_quantize/scripts/speed_eval.py`
#
# ## Env setup

# %%
# !pip install vllm datasets
# !pip install -U huggingface_hub

# %%
# Mount to my google drive:
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python speed_eval.py "tctsung/TinyLlama-1.1B-chat-v1.0-awq"
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# WARNING 05-17 15:15:59 config.py:205] awq quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# ...

# %%
# clean-up GPU memory
import gc
import torch
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
# !python speed_eval.py "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 608/608 [00:00<00:00, 3.70MB/s]
# WARNING 05-18 16:03:12 config.py:1086] Casting torch.bfloat16 to torch.float16.
# ...
